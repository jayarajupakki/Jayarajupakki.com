# %% [markdown]
# <a href="https://colab.research.google.com/github/jayarajupakki/Jayarajupakki.com/blob/main/RF_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip! install mpl_toolkits.basemap import Basemap
# Out:
# ERROR: unknown command "!"

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
pip install basemap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 860.7/860.7 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 41.5 MB/s eta 0:00:00
# ...

# %%
pip install matplotlib

# %%
pip install gdal

# %%
pip install numpy

# %%
pip install pandas

# %%
pip install pyshp

# %%
pip install geopandas

# %%
pip install xarray

# %%
pip install rasterio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 46.7 MB/s eta 0:00:00
# ...

# %%
pip install netcdf4
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 37.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.7 MB/s eta 0:00:00
# ...

# %%
pip install windrose

# %%
pip install cartopy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 59.2 MB/s eta 0:00:00
# ...

# %%
pip install plotly

# %%
pip install bottleneck
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.0/354.0 kB 4.3 MB/s eta 0:00:00
# ...

# %%
pip install scikit-learn

# %%
pip install pathlib

# %%
pip install seaborn

# %%
pip install termcolor

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
from osgeo import gdal
import numpy as np
import math
import pandas as pd
import shapefile as shp
import geopandas
import xarray
import rasterio
import glob
from rasterio.mask import mask

# %%
pip install salem
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.1 MB/s eta 0:00:00
# ...

# %%
import salem
from netCDF4 import Dataset
from windrose.windrose import WindroseAxes  # Correct the import statement for windrose
import matplotlib.cm as cm
import os
import cartopy
import cartopy.crs as ccrs
import matplotlib.ticker as mticker
import plotly.graph_objs as go  # Correct the import statement for plotly.graph_objs
import plotly.express as px
import datetime
import bottleneck
import calendar
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from pathlib import Path
import csv
import warnings
import seaborn as sns
import datetime as dt
from matplotlib.ticker import NullFormatter
from matplotlib.dates import MonthLocator, DateFormatter
from termcolor import colored
from mpl_toolkits.axes_grid1.inset_locator import inset_axes  # Correct the import statement for mpl_toolkits.axes_grid1.inset_locator

sns.set_style({'font.family':'sans-serif', 'font.serif':'Arial'})

# %%
plt.rcParams['legend.handlelength'] = 1
plt.rcParams['legend.handleheight'] = 1

SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 11

font = {'family' : 'sans-serif', 'serif' : 'Arial', 'size' : BIGGER_SIZE}
plt.rc('font', **font)

# %%
font = {'family' : 'sans-serif', 'serif' : 'Arial', 'size' : BIGGER_SIZE}
plt.rc('font', **font)
# plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
# rcParams['lines.linewidth'] = 0.4
plt.rc('axes', linewidth=0.7)  # fontsize of the figure title

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls '/content/drive/MyDrive/Proj_Covid'
# Out:
# RF_Model.ipynb  site_10820231105105313.xlsx  site_502420231105110557.xlsx

# %%
import pandas as pd
path='/content/drive/MyDrive/Proj_Covid/site_502420231105110557.xlsx'
my_data = pd.read_excel(path)

# %%
my_data.keys()
# Out:
# Index(['CENTRAL POLLUTION CONTROL BOARD', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')

# %%
my_data.head()
# Out:
#   CENTRAL POLLUTION CONTROL BOARD Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0  CONTINUOUS AMBIENT AIR QUALITY        NaN        NaN        NaN        NaN
# 1       Date: Sunday, Nov 05 2023        NaN        NaN        NaN        NaN
# 2               Time: 11:06:00 AM        NaN        NaN        NaN        NaN
# 3                           State      Delhi        NaN        NaN        NaN
# 4                            City      Delhi        NaN        NaN        NaN
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0        NaN        NaN        NaN
# 1        NaN        NaN        NaN
# 2        NaN        NaN        NaN
# 3        NaN        NaN        NaN
# 4        NaN        NaN        NaN

# %%
PM_2_5=my_data.head()

# %%
PM_2_5
# Out:
#   CENTRAL POLLUTION CONTROL BOARD Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0  CONTINUOUS AMBIENT AIR QUALITY        NaN        NaN        NaN        NaN
# 1       Date: Sunday, Nov 05 2023        NaN        NaN        NaN        NaN
# 2               Time: 11:06:00 AM        NaN        NaN        NaN        NaN
# 3                           State      Delhi        NaN        NaN        NaN
# 4                            City      Delhi        NaN        NaN        NaN
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0        NaN        NaN        NaN
# 1        NaN        NaN        NaN
# 2        NaN        NaN        NaN
# 3        NaN        NaN        NaN
# 4        NaN        NaN        NaN
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
print(my_data)
# Out:
#        CENTRAL POLLUTION CONTROL BOARD        Unnamed: 1 Unnamed: 2  \
# 0       CONTINUOUS AMBIENT AIR QUALITY               NaN        NaN
# 1            Date: Sunday, Nov 05 2023               NaN        NaN
# 2                    Time: 11:06:00 AM               NaN        NaN
# 3                                State             Delhi        NaN
# 4                                 City             Delhi        NaN
# ...                                ...               ...        ...
# 140172                30-12-2022 23:00  30-12-2022 23:15        354
# 140173                30-12-2022 23:15  30-12-2022 23:30        354
# 140174                30-12-2022 23:30  30-12-2022 23:45        354
# 140175                30-12-2022 23:45  31-12-2022 00:00        354
# 140176                31-12-2022 00:00  31-12-2022 00:00        411
#
#        Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0             NaN        NaN        NaN        NaN        NaN
# ...

# %%
my_data.values
# Out:
# array([['CONTINUOUS AMBIENT AIR QUALITY', nan, nan, ..., nan, nan, nan],
#        ['Date: Sunday, Nov 05 2023', nan, nan, ..., nan, nan, nan],
#        ['Time: 11:06:00 AM', nan, nan, ..., nan, nan, nan],
#        ...,
#        ['30-12-2022 23:30', '30-12-2022 23:45', 354, ..., 55, 78.5, 5.4],
#        ['30-12-2022 23:45', '31-12-2022 00:00', 354, ..., 43.3, 84.2,
#         4.7],
#        ['31-12-2022 00:00', '31-12-2022 00:00', 411, ..., 52.5, 82.8,
#         4.6]], dtype=object)

# %%
time_column = my_data.iloc[:, 0].values

# %%
pm25 = my_data.iloc[16:, 2].values

# %%
import numpy as np

# %%
missing_vals=["N/a",'na','nan',np.nan]
my_data = pd.read_excel(path,na_values=missing_vals)

# %%
my_data.isnull().sum()
my_data.fillna(method='bfill')
# Out:
#        CENTRAL POLLUTION CONTROL BOARD        Unnamed: 1 Unnamed: 2  \
# 0       CONTINUOUS AMBIENT AIR QUALITY             Delhi       0-60
# 1            Date: Sunday, Nov 05 2023             Delhi       0-60
# 2                    Time: 11:06:00 AM             Delhi       0-60
# 3                                State             Delhi       0-60
# 4                                 City             Delhi       0-60
# ...                                ...               ...        ...
# 140172                30-12-2022 23:00  30-12-2022 23:15        354
# 140173                30-12-2022 23:15  30-12-2022 23:30        354
# 140174                30-12-2022 23:30  30-12-2022 23:45        354
# 140175                30-12-2022 23:45  31-12-2022 00:00        354
# 140176                31-12-2022 00:00  31-12-2022 00:00        411
#
#        Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0           0-100      0-200      0-200      0-200      0-180
# ...

# %%
pm25 = my_data.iloc[16:, 2].values

# %%
pm25
# Out:
# array([338, 338, 385, ..., 354, 354, 411], dtype=object)

# %%
my_data.isnull().sum()
# Out:
# CENTRAL POLLUTION CONTROL BOARD     1
# Unnamed: 1                          6
# Unnamed: 2                         14
# Unnamed: 3                         14
# Unnamed: 4                         14
# Unnamed: 5                         14
# Unnamed: 6                         14
# Unnamed: 7                         14
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
pm25
# Out:
# array([338, 338, 385, ..., 354, 354, 411], dtype=object)
